# %%
name = str(input())
age=int(input())
height=float(input())
student=bool(input())
print("Name:",name)
print("Age:",age)
print("Height:",height)
print("Student:",student)
# Out:
# Dheeraj
# 20
# 6.1
# true
# Name: Dheeraj
# Age: 20
# Height: 6.1
# Student: True

# %%
name = str(input())
age=int(input())
height=float(input())
student=bool(input())
print(f"Name: {name} Age: {age} Height: {height} Student: {student}" )
# Out:
# Dheeraj
# 20
# 6.1
# true
# Name: Dheeraj Age: 20 Height: 6.1 Student: True

# %%
month_age=age*12;
days_age=month_age*365
rem=age%7
power_age=age*age
print(f"Months {month_age} Days {days_age} remainder {rem} power of age {power_age}")
# Out:
# Months 240 Days 87600 remainder 6 power of age 400
